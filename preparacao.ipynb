# %%
import pandas as pd
import boto3
import numpy as np
from sklearn.datasets import dump_svmlight_file 
import sagemaker
import os

# %%
bucket = 'datascience-sagemaker-viniciusfreire'

# %%
dados_brutos_arquivo = 'Case_cobranca.csv'

try:
    os.mkdir('dados')
except:
    pass

dados = pd.read_csv("s3://{}/{}".format(bucket, "Case_cobranca.csv"))
pd.set_option('display.max_rows', 20) 
dados
# Out:
#        COD TIPO_CLIENTE TIPO_EMPRESTIMO CD_SEXO  IDADE  QTD_DIVIDAS  \
# 0        1         NOVO             CDC       M   26.0            0
# 1        2         NOVO    RENEGOCIAÇÃO       M   39.0            0
# 2        3         NOVO         PESSOAL       M   31.0            1
# 3        4         NOVO         PESSOAL       F   45.0           11
# 4        5         NOVO             CDC       F   25.0            0
# ...    ...          ...             ...     ...    ...          ...
# 9812  9813         NOVO             CDC       F   38.0            1
# 9813  9814         NOVO    RENEGOCIAÇÃO       M   34.0            2
# 9814  9815      TOMADOR             CDC     NaN   30.0            4
# 9815  9816   INVESTIDOR             CDC       M   43.0            0
# 9816  9817         NOVO         PESSOAL     NaN   55.0           14
#
#       TEMP_RECUPERACAO
# 0                227.0
# 1                 37.0
# 2                  NaN
# 3                  NaN
# 4                  8.0
# ...                ...
# 9812              23.0
# 9813             234.0
# 9814              13.0
# 9815               6.0
# 9816               NaN
#
# [9817 rows x 7 columns]

# %%
dados['ALVO']   = dados['TEMP_RECUPERACAO'].apply(lambda x: 1 if x <= 90 else 0)
dados
# Out:
#        COD TIPO_CLIENTE TIPO_EMPRESTIMO CD_SEXO  IDADE  QTD_DIVIDAS  \
# 0        1         NOVO             CDC       M   26.0            0
# 1        2         NOVO    RENEGOCIAÇÃO       M   39.0            0
# 2        3         NOVO         PESSOAL       M   31.0            1
# 3        4         NOVO         PESSOAL       F   45.0           11
# 4        5         NOVO             CDC       F   25.0            0
# ...    ...          ...             ...     ...    ...          ...
# 9812  9813         NOVO             CDC       F   38.0            1
# 9813  9814         NOVO    RENEGOCIAÇÃO       M   34.0            2
# 9814  9815      TOMADOR             CDC     NaN   30.0            4
# 9815  9816   INVESTIDOR             CDC       M   43.0            0
# 9816  9817         NOVO         PESSOAL     NaN   55.0           14
#
#       TEMP_RECUPERACAO  ALVO
# 0                227.0     0
# 1                 37.0     1
# 2                  NaN     0
# 3                  NaN     0
# 4                  8.0     1
# ...                ...   ...
# 9812              23.0     1
# 9813             234.0     0
# 9814              13.0     1
# 9815               6.0     1
# 9816               NaN     0
#
# [9817 rows x 8 columns]

# %%
dados['CLIENTE_NOVO']   = dados['TIPO_CLIENTE'].apply(lambda x: 1 if x == 'NOVO' else 0)
dados['CLIENTE_INVESTIDOR']   = dados['TIPO_CLIENTE'].apply(lambda x: 1 if x == 'INVESTIDOR' else 0)             

dados
# Out:
#        COD TIPO_CLIENTE TIPO_EMPRESTIMO CD_SEXO  IDADE  QTD_DIVIDAS  \
# 0        1         NOVO             CDC       M   26.0            0
# 1        2         NOVO    RENEGOCIAÇÃO       M   39.0            0
# 2        3         NOVO         PESSOAL       M   31.0            1
# 3        4         NOVO         PESSOAL       F   45.0           11
# 4        5         NOVO             CDC       F   25.0            0
# ...    ...          ...             ...     ...    ...          ...
# 9812  9813         NOVO             CDC       F   38.0            1
# 9813  9814         NOVO    RENEGOCIAÇÃO       M   34.0            2
# 9814  9815      TOMADOR             CDC     NaN   30.0            4
# 9815  9816   INVESTIDOR             CDC       M   43.0            0
# 9816  9817         NOVO         PESSOAL     NaN   55.0           14
#
#       TEMP_RECUPERACAO  ALVO  CLIENTE_NOVO  CLIENTE_INVESTIDOR
# 0                227.0     0             1                   0
# 1                 37.0     1             1                   0
# 2                  NaN     0             1                   0
# 3                  NaN     0             1                   0
# 4                  8.0     1             1                   0
# ...                ...   ...           ...                 ...
# 9812              23.0     1             1                   0
# 9813             234.0     0             1                   0
# 9814              13.0     1             0                   0
# 9815               6.0     1             0                   1
# 9816               NaN     0             1                   0
#
# [9817 rows x 10 columns]

# %%
dados['EMPRESTIMO_CDC']   = dados['TIPO_EMPRESTIMO'].apply(lambda x: 1 if x == 'CDC' else 0)
dados['EMPRESTIMO_PESSOAL']   = dados['TIPO_EMPRESTIMO'].apply(lambda x: 1 if x == 'PESSOAL' else 0)
dados
# Out:
#        COD TIPO_CLIENTE TIPO_EMPRESTIMO CD_SEXO  IDADE  QTD_DIVIDAS  \
# 0        1         NOVO             CDC       M   26.0            0
# 1        2         NOVO    RENEGOCIAÇÃO       M   39.0            0
# 2        3         NOVO         PESSOAL       M   31.0            1
# 3        4         NOVO         PESSOAL       F   45.0           11
# 4        5         NOVO             CDC       F   25.0            0
# ...    ...          ...             ...     ...    ...          ...
# 9812  9813         NOVO             CDC       F   38.0            1
# 9813  9814         NOVO    RENEGOCIAÇÃO       M   34.0            2
# 9814  9815      TOMADOR             CDC     NaN   30.0            4
# 9815  9816   INVESTIDOR             CDC       M   43.0            0
# 9816  9817         NOVO         PESSOAL     NaN   55.0           14
#
#       TEMP_RECUPERACAO  ALVO  CLIENTE_NOVO  CLIENTE_INVESTIDOR  \
# 0                227.0     0             1                   0
# 1                 37.0     1             1                   0
# 2                  NaN     0             1                   0
# 3                  NaN     0             1                   0
# 4                  8.0     1             1                   0
# ...                ...   ...           ...                 ...
# 9812              23.0     1             1                   0
# 9813             234.0     0             1                   0
# 9814              13.0     1             0                   0
# 9815               6.0     1             0                   1
# 9816               NaN     0             1                   0
#
#       EMPRESTIMO_CDC  EMPRESTIMO_PESSOAL
# 0                  1                   0
# 1                  0                   0
# 2                  0                   1
# 3                  0                   1
# 4                  1                   0
# ...              ...                 ...
# 9812               1                   0
# 9813               0                   0
# 9814               1                   0
# 9815               1                   0
# 9816               0                   1
#
# [9817 rows x 12 columns]

# %%
dados['SEXO_M']   = dados['CD_SEXO'].apply(lambda x: 1 if x == 'M' else 0)
dados
# Out:
#        COD TIPO_CLIENTE TIPO_EMPRESTIMO CD_SEXO  IDADE  QTD_DIVIDAS  \
# 0        1         NOVO             CDC       M   26.0            0
# 1        2         NOVO    RENEGOCIAÇÃO       M   39.0            0
# 2        3         NOVO         PESSOAL       M   31.0            1
# 3        4         NOVO         PESSOAL       F   45.0           11
# 4        5         NOVO             CDC       F   25.0            0
# ...    ...          ...             ...     ...    ...          ...
# 9812  9813         NOVO             CDC       F   38.0            1
# 9813  9814         NOVO    RENEGOCIAÇÃO       M   34.0            2
# 9814  9815      TOMADOR             CDC     NaN   30.0            4
# 9815  9816   INVESTIDOR             CDC       M   43.0            0
# 9816  9817         NOVO         PESSOAL     NaN   55.0           14
#
#       TEMP_RECUPERACAO  ALVO  CLIENTE_NOVO  CLIENTE_INVESTIDOR  \
# 0                227.0     0             1                   0
# 1                 37.0     1             1                   0
# 2                  NaN     0             1                   0
# 3                  NaN     0             1                   0
# 4                  8.0     1             1                   0
# ...                ...   ...           ...                 ...
# 9812              23.0     1             1                   0
# 9813             234.0     0             1                   0
# 9814              13.0     1             0                   0
# 9815               6.0     1             0                   1
# 9816               NaN     0             1                   0
#
#       EMPRESTIMO_CDC  EMPRESTIMO_PESSOAL  SEXO_M
# 0                  1                   0       1
# 1                  0                   0       1
# 2                  0                   1       1
# 3                  0                   1       0
# 4                  1                   0       0
# ...              ...                 ...     ...
# 9812               1                   0       0
# 9813               0                   0       1
# 9814               1                   0       0
# 9815               1                   0       1
# 9816               0                   1       0
#
# [9817 rows x 13 columns]

# %%
dados['IDADE_NORM'] = dados['IDADE'].apply(lambda x: 18 if np.isnan(x) or x < 18 else x) # mínimo
dados['IDADE_NORM'] = dados['IDADE_NORM'].apply(lambda x: 76 if x > 76 else x) # máximo
dados['IDADE_NORM'] = dados['IDADE_NORM'].apply(lambda x: (x-18)/(76-18)) # normalização entre 0 e 1
dados
# Out:
#        COD TIPO_CLIENTE TIPO_EMPRESTIMO CD_SEXO  IDADE  QTD_DIVIDAS  \
# 0        1         NOVO             CDC       M   26.0            0
# 1        2         NOVO    RENEGOCIAÇÃO       M   39.0            0
# 2        3         NOVO         PESSOAL       M   31.0            1
# 3        4         NOVO         PESSOAL       F   45.0           11
# 4        5         NOVO             CDC       F   25.0            0
# ...    ...          ...             ...     ...    ...          ...
# 9812  9813         NOVO             CDC       F   38.0            1
# 9813  9814         NOVO    RENEGOCIAÇÃO       M   34.0            2
# 9814  9815      TOMADOR             CDC     NaN   30.0            4
# 9815  9816   INVESTIDOR             CDC       M   43.0            0
# 9816  9817         NOVO         PESSOAL     NaN   55.0           14
#
#       TEMP_RECUPERACAO  ALVO  CLIENTE_NOVO  CLIENTE_INVESTIDOR  \
# 0                227.0     0             1                   0
# 1                 37.0     1             1                   0
# 2                  NaN     0             1                   0
# 3                  NaN     0             1                   0
# 4                  8.0     1             1                   0
# ...                ...   ...           ...                 ...
# 9812              23.0     1             1                   0
# 9813             234.0     0             1                   0
# 9814              13.0     1             0                   0
# 9815               6.0     1             0                   1
# 9816               NaN     0             1                   0
#
#       EMPRESTIMO_CDC  EMPRESTIMO_PESSOAL  SEXO_M  IDADE_NORM
# 0                  1                   0       1    0.137931
# 1                  0                   0       1    0.362069
# 2                  0                   1       1    0.224138
# 3                  0                   1       0    0.465517
# 4                  1                   0       0    0.120690
# ...              ...                 ...     ...         ...
# 9812               1                   0       0    0.344828
# 9813               0                   0       1    0.275862
# 9814               1                   0       0    0.206897
# 9815               1                   0       1    0.431034
# 9816               0                   1       0    0.637931
#
# [9817 rows x 14 columns]

# %%
dados['QTD_DIVIDAS_NORM'] = dados['QTD_DIVIDAS'].apply(lambda x: 0. if np.isnan(x) else x/16) # normalização entre 0 e 1
dados
# Out:
#        COD TIPO_CLIENTE TIPO_EMPRESTIMO CD_SEXO  IDADE  QTD_DIVIDAS  \
# 0        1         NOVO             CDC       M   26.0            0
# 1        2         NOVO    RENEGOCIAÇÃO       M   39.0            0
# 2        3         NOVO         PESSOAL       M   31.0            1
# 3        4         NOVO         PESSOAL       F   45.0           11
# 4        5         NOVO             CDC       F   25.0            0
# ...    ...          ...             ...     ...    ...          ...
# 9812  9813         NOVO             CDC       F   38.0            1
# 9813  9814         NOVO    RENEGOCIAÇÃO       M   34.0            2
# 9814  9815      TOMADOR             CDC     NaN   30.0            4
# 9815  9816   INVESTIDOR             CDC       M   43.0            0
# 9816  9817         NOVO         PESSOAL     NaN   55.0           14
#
#       TEMP_RECUPERACAO  ALVO  CLIENTE_NOVO  CLIENTE_INVESTIDOR  \
# 0                227.0     0             1                   0
# 1                 37.0     1             1                   0
# 2                  NaN     0             1                   0
# 3                  NaN     0             1                   0
# 4                  8.0     1             1                   0
# ...                ...   ...           ...                 ...
# 9812              23.0     1             1                   0
# 9813             234.0     0             1                   0
# 9814              13.0     1             0                   0
# 9815               6.0     1             0                   1
# 9816               NaN     0             1                   0
#
#       EMPRESTIMO_CDC  EMPRESTIMO_PESSOAL  SEXO_M  IDADE_NORM  QTD_DIVIDAS_NORM
# 0                  1                   0       1    0.137931            0.0000
# 1                  0                   0       1    0.362069            0.0000
# 2                  0                   1       1    0.224138            0.0625
# 3                  0                   1       0    0.465517            0.6875
# 4                  1                   0       0    0.120690            0.0000
# ...              ...                 ...     ...         ...               ...
# 9812               1                   0       0    0.344828            0.0625
# 9813               0                   0       1    0.275862            0.1250
# 9814               1                   0       0    0.206897            0.2500
# 9815               1                   0       1    0.431034            0.0000
# 9816               0                   1       0    0.637931            0.8750
#
# [9817 rows x 15 columns]

# %%
dados = dados.drop(['COD', 'TIPO_CLIENTE', 'TIPO_EMPRESTIMO', 'CD_SEXO', 'IDADE', 'QTD_DIVIDAS', 'TEMP_RECUPERACAO'], axis=1)
dados
# Out:
#       ALVO  CLIENTE_NOVO  CLIENTE_INVESTIDOR  EMPRESTIMO_CDC  \
# 0        0             1                   0               1
# 1        1             1                   0               0
# 2        0             1                   0               0
# 3        0             1                   0               0
# 4        1             1                   0               1
# ...    ...           ...                 ...             ...
# 9812     1             1                   0               1
# 9813     0             1                   0               0
# 9814     1             0                   0               1
# 9815     1             0                   1               1
# 9816     0             1                   0               0
#
#       EMPRESTIMO_PESSOAL  SEXO_M  IDADE_NORM  QTD_DIVIDAS_NORM
# 0                      0       1    0.137931            0.0000
# 1                      0       1    0.362069            0.0000
# 2                      1       1    0.224138            0.0625
# 3                      1       0    0.465517            0.6875
# 4                      0       0    0.120690            0.0000
# ...                  ...     ...         ...               ...
# 9812                   0       0    0.344828            0.0625
# 9813                   0       1    0.275862            0.1250
# 9814                   0       0    0.206897            0.2500
# 9815                   0       1    0.431034            0.0000
# 9816                   1       0    0.637931            0.8750
#
# [9817 rows x 8 columns]

# %%
treinamento, validacao, teste = np.split(dados.sample(frac=1, random_state=88), [int(0.7 * len(dados)), int(0.9 * len(dados))]) 
len(dados),len(treinamento), len(validacao), len(teste)
# Out:
# (9817, 6871, 1964, 982)

# %%
treinamento.to_csv('dados/treinamento.csv', index=False, header=False)
validacao.to_csv('dados/validacao.csv', index=False, header=False)
teste.to_csv('dados/teste.csv', index=False)

# %%
boto3.Session().resource('s3').Bucket(bucket).Object('treinamento.csv').upload_file('dados/treinamento.csv')
boto3.Session().resource('s3').Bucket(bucket).Object('validacao.csv').upload_file('dados/validacao.csv')
boto3.Session().resource('s3').Bucket(bucket).Object('teste.csv').upload_file('dados/teste.csv')
